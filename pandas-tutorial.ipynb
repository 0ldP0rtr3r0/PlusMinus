# %% [markdown]
# ## Getting Setup with Pandas

# %%
#### This is where you install Libraries and where Jupyter accesses Python 

# import sys
# print(sys.executable)

# %% [markdown]
# ## Importing with Pandas

# %%
import pandas as pd

#### Import a data file with pandas

## import .csv data file as df ---
df = pd.read_csv('Datasets/pokemon_data.csv')
## import .txt data file as df ---
#df = pd.read_csv('Datasets/pokemon_data.csv', delimiter='\t')
## import .xlsx data file as df ---
#df = pd.read_excel('Datasets/pokemon_data.xlsx')

## Print the data file ---
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ## Reading Data in Pandas

# %%
#### Read Headers

# print(df.columns)

### Read each Column
# print(df['Name'])
# print(df['Name'][0:5])
# print(df[['Name', 'Type 1', 'HP']])

### Read each Row
# print(df.head(4))
# print(df.iloc[1]) --- # iloc = integer location
# print(df.iloc[0:4])

### Read row by row
# for index, row in df.iterrows():
    # print(index, row)
    # print(index, row['Name'])

### df.loc ~ returns highly specified data with conditions; no condition limit
# df.loc[df['Type 1'] == "Fire"]
# df.loc[df['Type 1'] == "Dragon"]

### Read a specific location (Row, Column)
# print(df.iloc[2,1])
# Out:
#        #                     Name  Type 1    Type 2   HP  Attack  Defense  \
# 159  147                  Dratini  Dragon       NaN   41      64       45
# 160  148                Dragonair  Dragon       NaN   61      84       65
# 161  149                Dragonite  Dragon    Flying   91     134       95
# 365  334                  Altaria  Dragon    Flying   75      70       90
# 366  334      AltariaMega Altaria  Dragon     Fairy   75     110      110
# 406  371                    Bagon  Dragon       NaN   45      75       60
# 407  372                  Shelgon  Dragon       NaN   65      95      100
# 408  373                Salamence  Dragon    Flying   95     135       80
# 409  373  SalamenceMega Salamence  Dragon    Flying   95     145      130
# 417  380                   Latias  Dragon   Psychic   80      80       90
# 418  380        LatiasMega Latias  Dragon   Psychic   80     100      120
# 419  381                   Latios  Dragon   Psychic   80      90       80
# ...

# %% [markdown]
# ## Sorting / Describing Data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...
